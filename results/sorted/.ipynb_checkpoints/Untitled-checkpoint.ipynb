# %%
import os
import numpy as np 
import pandas as pd
import glob

# %%
# real data tree summarize
log_file_dir = "../realdata_tree"

ST_table = pd.read_csv("../realdata_tree/ST.txt",header = None)
ST_table.to_csv("../realdata_tree/ST.csv", header = None, index = None)



method_seq = glob.glob("{}/*.csv".format(log_file_dir))
method_seq = [os.path.split(method)[1].split('.')[0] for method in method_seq]

print(method_seq)
summarize_log=pd.DataFrame([])

for method in method_seq:
    log = pd.read_csv("{}/{}.csv".format(log_file_dir,method), header=None)
    log.columns = "dataset,mse,time,iteration".split(',')
    log["method"]=method
    summarize_log=summarize_log.append(log)
    
    
summary = pd.pivot_table(summarize_log, index=["method"],columns=["dataset"], values=[ "mse","time"], aggfunc=[np.mean, np.std, len])
# Out:
# ['RTER', 'PRT_val', 'RTER_pure', 'STRT_no_selection', 'STRT', 'ST', 'DT']

# %%
significance_test(summarize_log,summary)
# Out:
# [-0.99380808 -1.45108204 -1.14994709 -1.35645077 -1.31157594]
# [-1.72854826 -1.15468345 -1.40720075 -1.11720597 -1.17798925]
# [-0.52043809 -0.95426993 -0.70406069 -0.60824223 -0.65631502]
# [-0.59125964 -0.73945786 -0.52022013 -0.70669474 -0.82481439]
# [-1.127541 -0.208214 -1.31291  -0.884955 -0.135555]
# [-1.453431 -1.03559  -1.731861 -0.628604  0.131789]
# [-1.60878069 -1.72082258 -0.74541725 -2.80024511 -7.76764073]
# [-21.86666571 -21.66850028 -20.68999755 -22.93346245 -22.43994064]
# [-0.87232549 -0.54982745  2.38026386  0.17156506 -1.39726049]
# [-18.02196284 -15.8597203  -13.16547805 -13.30278349 -15.62011139]
# [-3.693669 -5.017906 -1.982644 -5.635642 -3.532944]
# [ -4.482693  -5.238803 -22.062855  -4.91814   -3.083241]
# [-0.02148363  0.00223528  0.01373276 -0.02264738 -0.02028031]
# [-0.00879579 -0.01159858 -0.00980044 -0.0003704   0.01562445]
# [-0.06128912 -0.09676188 -0.05353946 -0.12498104 -0.01833789]
# [-0.21062979 -0.24395709 -0.23049764 -0.21648886 -0.19233916]
# [ 0.00417521 -0.01226409 -0.01005764 -0.00973886  0.01710884]
# [-0.00929679 -0.02321609 -0.00379264 -0.01467086  0.01283784]
# [-1.33465263 -0.67914623 -1.16017826 -0.73018305 -0.13563564]
# [-0.76652656 -0.2419439  -0.71468568 -0.48541983  0.28512868]
# [-1.2060544  -0.55483157 -1.00988718 -1.05778596 -0.02296516]
# [-1.25409767 -1.00977873 -0.72086172 -1.30872422 -0.2308666 ]
# [-1.755441 -1.344799 -1.34778  -1.761525 -0.406038]
# [-0.140141 -0.017389 -0.03729  -0.0747    0.181943]
# [-0.0741514  -0.09471053 -0.14655424 -0.0891696  -0.14882106]
# [-0.45227533 -0.52355848 -0.50512297 -0.41948643 -0.5045712 ]
# [-2.44043054 -1.35499253 -2.53306451 -1.83498312 -1.79093642]
# [-0.31216666 -0.25130094 -0.35727866 -0.1848943  -0.13403287]
# [-0.29700566 -0.37011794 -0.41421866 -0.3451483  -0.32918287]
# [-105361.86680966 -231372.59105158  -52097.5430001  -172490.6542508
#   -78823.56809252]
# [-43005.55472582 -60362.5933963  -58519.47414849 -52983.4707509
#  -38720.0997551 ]
# [ -50413.53336449 -304497.39665864 -264681.20989547 -388837.18500129
#  -114379.85856374]
# [-1046513.33475148 -1247508.04696052 -1109039.65192538 -1303195.1755525
# [-0.00822376 -0.00616948 -0.00831194 -0.00664311 -0.00704818]
# [-0.00152301 -0.00169735 -0.00239187 -0.00027392 -0.00189203]
# [-8.00656890e-04 -2.48463308e-04  6.36651553e-05 -8.79661648e-04
#   8.29654370e-04]
# [-0.00972696 -0.00192996 -0.00531273  0.00038504  0.00433075]
# [-0.00520296 -0.00071096 -0.00922373 -0.00368396  0.00410075]
# [-0.02117922 -0.02638901 -0.04384306 -0.06558286 -0.01476323]
# [-0.03177179 -0.04125178 -0.08458729 -0.083915   -0.05997632]
# [-0.03700777 -0.01430473 -0.03102423 -0.05520968 -0.02134695]
# [-0.06389218 -0.16273573 -0.0499615  -0.10130637 -0.05580263]
# [-7.2000e-05 -1.7590e-03 -4.5700e-03 -1.8794e-02 -2.1134e-02]
# [-0.07034564  0.1164775  -0.19900645 -0.76351361 -1.77595085]
# [-15.33895151 -23.81459856 -17.93616621 -16.59772394 -25.67282239]
# [-0.14715065 -0.63749819 -2.47508641 -1.50402519 -2.57509867]
# [-143.22011926 -137.23581744  -78.43593132 -100.3137764  -170.95819127]
# [-207.220681 -267.696029 -212.194443 -204.366225 -219.869691]
# [ 1.157859 -0.225903 -0.465626 -1.935999  0.474539]
# [['abalone', 0],
#  ['airfoil', 0],
#  ['algerian', 0],
#  ['aquatic', 0],
#  ['bias', 1],
#  ['building', 0],
#  ['cbm', 0],
#  ['ccpp', 0],
#  ['communities', 0],
#  ['concrete', 0],
#  ['cpusmall_scale', 0],
#  ['dakbilgic', 1],
#  ['facebook', 5],
#  ['fish', 0],
#  ['forestfires', 0],
#  ['housing_scale', 0],
#  ['mg_scale', 0],
#  ['mpg_scale', 0],
#  ['music', 0],
#  ['portfolio', 0],
#  ['redwine', 0],
#  ['space_ga_scale', 0],
#  ['whitewine', 1],
#  ['yacht', 0]]

# %%
def significance_test(log, summary, sig_level = 0.05, criterion = "mse"):
    
    
    sig_result_vec = []
    
    for data_name in list(summary["mean"][criterion].columns):
        
        mean_seq = summary["mean"][criterion][data_name]
        
        best_method = mean_seq.index[mean_seq.argmin()]
        
        num_sig = 0
        
        # get two test seq 
        for method in list(mean_seq.index):
          
            if best_method == method:
                continue
            seq_best = log[(log["dataset"] == data_name) * (log["method"] == best_method)][criterion].to_numpy()
            seq_test = log[(log["dataset"] == data_name) * (log["method"] == method)][criterion].to_numpy()
            
            
           
            if seq_test.shape[0]==0:
                num_sig +=1
            else:
                print(seq_best-seq_test)
                if wilcoxon(seq_best-seq_test, alternative = "less").pvalue < sig_level:
                    num_sig +=1
                    print(1)
            
        sig_result_vec.append([data_name, num_sig])
        
        
    return sig_result_vec

# %%
mean_seq = summary["mean"]["mse"]["abalone"]

# %%
mean_seq.index[mean_seq.argmin()]
# Out:
# 'ST'

# %%
mean_seq
# Out:
# method
# DT           5.742003
# PRT_val      5.806556
# RTER         5.178095
# RTER_pure    5.165919
# ST           4.489430
# STRT         5.223265
# Name: abalone, dtype: float64

# %%
test_seq = summarize_log[(summarize_log["dataset"] == "abalone") * ( summarize_log["method"] == "RTER")]["mse"].to_numpy()

# %%
list(mean_seq.index)
# Out:
# ['DT', 'PRT_val', 'RTER', 'RTER_pure', 'ST', 'STRT']

# %%
import scipy

# %%
from scipy.stats import wilcoxon

wilcoxon(test_seq).pvalue
# Out:
# 0.0625
